# %%
import pandas as pd

# %%
ns = pd.read_csv('noshow.csv', index_col=0)

# %%
ns.columns.tolist()
# Out:
# ['SERVICO',
#  'CENTRAL_DE_REGULACAO_RESPONSAVEL',
#  'MUNICIPIO_DE_RESIDENCIA',
#  'CLASSIFICACAO',
#  'TIPO_DA_LISTA',
#  'DOCUMENTO',
#  'DATA_DA_SOLICITACAO',
#  'DATA_DA_MARCACAO',
#  'DATA_DA_EXECUCAO',
#  'CIDADAO',
#  'NASCIMENTO',
#  'DESCRICAO_DO_PROCEDIMENTO',
#  'CNES_ESTABELECIMENTO_SOLICITANTE',
#  'CNES_CENTRAL_REGULADORA_SOLICITANTE',
#  'CNES_ESTABELECIMENTO_EXECUTANTE',
#  'DESCRICAO_ESTABELECIMENTO_EXECUTANTE',
#  'CODIGO_SIGTAP_DO_PROCEDIMENTO',
#  'DESCRICAO_DO_GRUPO_DO_PROCEDIMENTO',
#  'CONFIRMADO',
#  'noshow',
#  'ANO_NASCIMENTO',
#  'DTNOW',
#  'NOW',
#  'IDADE']

# %%
ns.head()
# Out:
#      SERVICO                CENTRAL_DE_REGULACAO_RESPONSAVEL  \
# 4   Consulta  CENTRAL DE REGULAÇÃO MUNICIPAL DE ÁGUAS MORNAS
# 5   Consulta   COMPLEXO REGULADOR ESTADUAL DE SANTA CATARINA
# 44  Consulta   COMPLEXO REGULADOR ESTADUAL DE SANTA CATARINA
# 52  Consulta  CENTRAL DE REGULAÇÃO MUNICIPAL DE ÁGUAS MORNAS
# 53  Consulta   COMPLEXO REGULADOR ESTADUAL DE SANTA CATARINA
#
#                      MUNICIPIO_DE_RESIDENCIA CLASSIFICACAO      TIPO_DA_LISTA  \
# 4                    UNIDADE DE SAUDE CENTRO      4 - Azul  Ordem cronologica
# 5                           CS VARGEM GRANDE      4 - Azul  Ordem cronologica
# 44  CENTRO DE ESPECIALIDADES ORLANDO BARRETO     3 - Verde  Ordem cronologica
# 52                   UNIDADE DE SAUDE CENTRO      4 - Azul  Ordem cronologica
# 53  SECRETARIA MUNICIPAL DE SAUDE DE BIGUACU      4 - Azul  Ordem cronologica
#
#           DOCUMENTO DATA_DA_SOLICITACAO  DATA_DA_MARCACAO  \
# 4   898000081202646      25-10-2010 0:0  26-03-2019 10:19
# ...

# %%
ns.CONFIRMADO.value_counts()
# Out:
# Series([], Name: CONFIRMADO, dtype: int64)

# %%
ns.CLASSIFICACAO.value_counts()
# Out:
# 4 - Azul        482797
# 3 - Verde        70028
# 2 - Amarelo      56034
# 1 - Vermelho     12658
# Name: CLASSIFICACAO, dtype: int64

# %%
X = df['IDADE',
       'MUNICIPIO_DE_RESIDENCIA',
       'CLASSIFICACAO',
       'CONFIRMADO']
